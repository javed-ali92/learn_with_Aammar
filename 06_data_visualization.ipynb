# %% [markdown]
# # Data Visualization
# #dataviz #datavisualization #codanic

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import titanic data from seaborn library
df = sns.load_dataset('titanic')

# %%
df.plot(kind='scatter', x='age', y='fare')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
df.plot(kind='scatter', x='age', y='fare', color = 'red')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# change colors using hex code
df.plot(kind='scatter', x='age', y='fare', color = '#2CB335')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.groupby('sex')['age'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='sex'>

# %%
df.groupby('sex')['fare'].mean().plot(kind='bar')
plt.ylabel('Average Fare')
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
# seaborn plots
# bar plot using seaborn on df
sns.barplot(data = df, x= 'survived', y='fare')
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.barplot(data = df, x= 'sex', y='fare', hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.barplot(data = df, x= 'sex', y='age', hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(data = df, x= 'sex', y='age', hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.scatterplot(data = df, x= 'fare', y='age', hue='sex')
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.scatterplot(data = df, y= 'fare', x='age', hue='class')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(data = df, y= 'fare', x='age', hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
pip install nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\dell\miniconda3\envs\python_eda\lib\site-packages (5.9.2)
# Requirement already satisfied: fastjsonschema in c:\users\dell\miniconda3\envs\python_eda\lib\site-packages (from nbformat) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\dell\miniconda3\envs\python_eda\lib\site-packages (from nbformat) (4.19.2)
# Requirement already satisfied: jupyter-core in c:\users\dell\miniconda3\envs\python_eda\lib\site-packages (from nbformat) (5.4.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\dell\miniconda3\envs\python_eda\lib\site-packages (from nbformat) (5.11.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dell\miniconda3\envs\python_eda\lib\site-packages (from jsonschema>=2.6->nbformat) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dell\miniconda3\envs\python_eda\lib\site-packages (from jsonschema>=2.6->nbformat) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dell\miniconda3\envs\python_eda\lib\site-packages (from jsonschema>=2.6->nbformat) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dell\miniconda3\envs\python_eda\lib\site-packages (from jsonschema>=2.6->nbformat) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dell\miniconda3\envs\python_eda\lib\site-packages (from jupyter-core->nbformat) (3.11.0)
# Requirement already satisfied: pywin32>=300 in c:\users\dell\miniconda3\envs\python_eda\lib\site-packages (from jupyter-core->nbformat) (306)
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install plotly

# %%
# make scatter plot via plotly
import plotly.express as px

fig = px.scatter(df, x= 'age', y='fare', color ='class')
fig.show()
# Out:
# c:\Users\Dell\miniconda3\envs\python_eda\Lib\site-packages\plotly\express\_core.py:2044: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(required_grouper, sort=False)  # skip one_group groupers

# %%
import plotly.graph_objects as go

import pandas as pd

# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

fig = go.Figure(data=[go.Surface(z=z_data.values)])

fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.show()

# %%
import plotly.express as px
df = px.data.gapminder()
px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])
